# %%
class EmptyDequeError(Exception):
    pass

class Node:
    def __init__(self, value):
        self.info = value
        self.prev = None
        self.next = None
        
class Deque:
    def __init__(self):
        self.front = None # first node
        self.rear = None # last node
        
    def is_empty(self):
        return self.front == None
    
    def size(self):
        count = 0
        p = self.front
        while p is not None:
            count += 1
            p = p.next
        return count

    def insert_front(self, item):
        temp = Node(item) # alloacting a new node
        if self.is_empty():
            self.front = self.rear = temp
        else:
            temp.next = self.front
            self.front.prev = temp
            self.front = temp
    
    def insert_rear(self, item):
        temp = Node(item) # alloacting a new node
        if self.is_empty():
            self.front = self.rear = temp
        else:
            self.rear.next = temp
            temp.prev = self.rear
            
        self.rear = temp

    def delete_front(self):
        if self.is_empty():
            raise EmptyDequeError("Deque is Empty")
    
        x = self.front.info
        if self.front.next is None:
            self.front = self.rear = None
        else:
            self.front = self.front.next
            self.front.prev = None
        return x
    
    def delete_rear(self):
        if self.is_empty():
            raise EmptyDequeError("Deque is Empty")
    
        x = self.rear.info
        if self.front.next is None:
            self.front = self.rear = None
        else:
            self.rear = self.rear.prev
            self.rear.next = None
        return x

    def first(self): 
        if self.is_empty():
            raise EmptyDequeError("Queue is empty")
        return self.front.info
    
    def last(self):
        if self.is_empty():
            raise EmptyDequeError("Queue is empty")
        return self.rear.info 
    
    def display(self):
        if self.is_empty():
            print("Queue is empty")
            return
        
        print("List is: ")
        p = self.front
        while p is not None:
            print(p.info, " ")
            p = p.next
        print()

# %%
if __name__ == "__main__":
    qu = Deque()
    
    while True:
        print("1.Insert at the front end")
        print("2.insert at the rear end")
        print("3.Delete from front end")
        print("4.Delete from rear end")
        print("5.Display first element")
        print("6.Display last element")
        print("7.Display")
        print("8.Size")
        print("9.Quit")
        
        choice = int(input("Enter your choice: "))
        
        if choice == 1:
            x = int(input("Enter the element: "))
            qu.insert_front(x)
        elif choice == 2:
            x = int(input("Enter the element: "))
            qu.insert_rear(x)
        elif choice == 3:
            x = qu.delete_front()
            print("Element deleted from front end is: ", x)
        elif choice == 4:
            x = qu.delete_rear()
            print("Element deleted from rear end is: ", x)
        elif choice == 5:
            print("First element is: ", qu.first())
        elif choice == 6:
            print("Last element is: ", qu.last())
        elif choice == 7:
            qu.display()
        elif choice == 8:
            print("Size of Deque ", qu.size())
        elif choice == 9:
            break
        else:
            print("Wrong choice")
        print()
# Out:
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 1
# Enter the element: 11
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 1
# Enter the element: 22
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 2
# Enter the element: 33
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 2
# Enter the element: 44
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 7
# List is:
# 22
# 11
# 33
# 44
#
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 3
# Element deleted from front end is:  22
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 7
# List is:
# 11
# 33
# 44
#
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 4
# Element deleted from rear end is:  44
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 7
# List is:
# 11
# 33
#
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 5
# First element is:  11
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 6
# Last element is:  33
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 7
# List is:
# 11
# 33
#
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 8
# Size of Deque  2
#
# 1.Insert at the front end
# 2.insert at the rear end
# 3.Delete from front end
# 4.Delete from rear end
# 5.Display first element
# 6.Display last element
# 7.Display
# 8.Size
# 9.Quit
# Enter your choice: 9
